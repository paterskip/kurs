# %% [markdown]
# if test expression:
#     statement(s)
#
# Jeśli test expression == true , przejście do statemate i wykonanie
#
# None and 0 are interpreted as **False**
#
#
# https://cdn.programiz.com/sites/tutorial2program/files/Python_if_statement.jpg

# %%
# If the number is positive, we print an appropriate message

num = 3
if num > 0:
    print(num, "is a positive number.")
print("This is always printed.")

num = -1
if num > 0:
    print(num, "is a positive number.")
print("This is also always printed.")

# %% [markdown]
# Jak widzimy :
# Zmienna num = 3 , lecimy z warunkiem , jeśli num > 0 to wyprituj. Bardzo prosty warunek. If == true , przejście dalej i wykonanie , if == False , w powyższym przypadku , zakończenie działania programu.

# %% [markdown]
# If / else
#
# Budowa :
#
# if test expression:
#     Body of if
# else:
#     Body of else
#
# Jeśli if == False , przejście do else.
# Jeśli if == True , wykonanie i pominięcie else.

# %%
# Program checks if the number is positive or negative
# And displays an appropriate message

num = -2

# Try these two variations as well. 
# num = -5
# num = 0

if num >= 0:
    print("Positive or Zero")
else:
    print("Negative number")
# Out:
# Negative number

# %% [markdown]
# - 2 jest mniejsze od 0 , więc if == Fale , stąd przejście z kodem d else i wykonanie print ze str "Negative number".

# %% [markdown]
# Kolejnym krokiem jest w warunkach jest bardziej rozbudowany schemat :
# if / elif / else
#
# Możemy zagnieżdzać , jak tutaj :

# %%
num = float(input("Enter a number: "))
if num >= 0:
    if num == 0:
        print("Zero")
    else:
        print("Positive number")
else:
    print("Negative number")
# Out:
# Enter a number: 5
# Positive number

# %% [markdown]
# Pobieramy od użytkownika liczbę , jeśli większa lub równa zero , przechodzi do :
#
# if num == 0:
#         print("Zero")
#     else:
#         print("Positive number")
#  I jeśli jest zerem to wypisze "Zero", a jeśli >0 to "Positive number"
#
#  Natomiast jeśli mniejsze od zera przechodzi dalej bo pierwszy if == False więcj omija tą część kodu i przechodzi na koniec wypisując "Negative number"

# %% [markdown]
# Liczby od 1500 do 2701 ( włącznie z krańcami ) , podzielne przez 7 i wielokrotność liczby 5
#
# Wielokrotność liczby :
# Wielokrotności liczby otrzymujesz mnożąc daną liczbę przez kolejne liczby naturalne. 0 jest wielokrotnością każdej liczby naturalnej.
# Wielokrtoność liczby 5 :
# 5 * 0 = 0
# 5 * 1 = 5
# 5 * 2 = 10
# 5 * 3 = 15
# 5 * 4 = 20
# 5 * 5 = 25
# 5 * 6 = 30 itd.

# %% [raw]
# nl=[]
# for x in range(1500, 2701):
#     if (x%7==0) and (x%5==0):
#         nl.append(str(x))
# print (','.join(nl))

# %% [raw]
# Kroki :
# 1) Utworzenie pustej listy nl
# 2) pętla for : zakres liczb podzielnych przez
